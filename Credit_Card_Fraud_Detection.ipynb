# %% [markdown]
# <a href="https://colab.research.google.com/github/Ismail-Amodu/Credit-Card-Fraud-Detection-Using-Python-ML-Project-05/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the dependencies

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading dataset into pandas dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# Printing the first five rows of the data
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# The last five rows of the data
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 5969  6634 -1.611463  0.190648  0.901715  1.531254 -1.535865  0.799245
# 5970  6635 -1.420272  1.449354  1.320110 -1.894320  0.913695  0.454601
# 5971  6637 -1.206696  0.284728  2.152053 -2.850437 -0.437285 -0.238376
# 5972  6644  1.067611  0.091006 -0.153917  0.704233  0.113894 -0.826866
# 5973  6645 -0.535272 -0.132299  2.180041  1.018303 -1.498819  0.529570
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 5969  1.513786  0.495829  0.200390  ...  0.211223  0.007477  1.026272
# 5970  0.894179 -0.385450  2.433841  ... -0.529027 -0.368394 -0.247773
# 5971 -0.333341  0.334679  2.870542  ...  0.039460  0.464476 -0.457193
# 5972  0.567690 -0.464181  0.957295  ... -0.476723 -1.410090 -0.037550
# 5973  0.420147  0.045445  1.543919  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# Getting number of rows and column
credit_card_data.shape
# Out:
# (5974, 31)

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5974 non-null   int64
#  1   V1      5974 non-null   float64
#  2   V2      5974 non-null   float64
#  3   V3      5974 non-null   float64
#  4   V4      5974 non-null   float64
#  5   V5      5974 non-null   float64
#  6   V6      5974 non-null   float64
#  7   V7      5974 non-null   float64
#  8   V8      5974 non-null   float64
#  9   V9      5974 non-null   float64
#  10  V10     5974 non-null   float64
#  11  V11     5974 non-null   float64
#  12  V12     5974 non-null   float64
#  13  V13     5974 non-null   float64
#  14  V14     5974 non-null   float64
#  15  V15     5974 non-null   float64
#  16  V16     5974 non-null   float64
#  17  V17     5974 non-null   float64
#  18  V18     5973 non-null   float64
#  19  V19     5973 non-null   float64
# ...

# %%
# Checking the number of missing values
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# **Handling the missing values: Dropping Method**

# %%
new_credit_card_data = credit_card_data.dropna(how='any')

# %%
new_credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Getting the distribution of transactions

# %%
# Obtaining the distribution of legit transaction and fraudulent transactions
new_credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    5970
# 1.0       3
# Name: count, dtype: int64

# %% [markdown]
# Handling The Highly Imbalanced data Encountered
#
#
# 1.   Normal/Legit transaction --> 0
# 2.   Fraudulent transaction --> 1

# %%
# Separating the data for analysis
legit = new_credit_card_data[new_credit_card_data.Class == 0]
fraud = new_credit_card_data[new_credit_card_data.Class == 1]

# %%
print(legit.shape)
# Out:
# (5970, 31)

# %%
print(fraud.shape)
# Out:
# (3, 31)

# %% [markdown]
# Getting the statistical measures of the data

# %%
legit.Amount.describe()
# Out:
# count    5970.000000
# mean       64.965707
# std       192.429839
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.485000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# Comparing the values for both transactions
new_credit_card_data.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    2677.40201 -0.264965  0.285625  0.844580  0.102656  0.000958  0.195420
# 1.0    1780.00000 -2.553039  0.184644 -0.293711  2.872264  0.005330 -0.855718
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.018542 -0.039195  0.397472  ...  0.055426 -0.043268 -0.161540
# 1.0   -0.549831  0.308239 -1.093098  ...  0.599742  0.294921 -0.177321
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.036683  0.028985  0.089890 -0.040132  0.025238  0.006163   64.965707
# 1.0    0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847  256.310000
#
# [2 rows x 30 columns]

# %% [markdown]
# **UNDER-SAMPLING**

# %%
# Bulding  a sample dataset containing similar distribution of legit/normal transaction and fraudulent transaction

legit_sample = legit.sample(n=25)

# %%
# Concatenating two dataframes
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3231  2797 -0.458755  0.605384  1.176174 -2.150163  0.300584 -0.830793
# 4001  3641  1.309282  0.399733  0.319851  0.622603  0.096517 -0.436800
# 3355  2907 -0.495710  1.156641  1.467784  0.060366 -0.112325 -1.186407
# 1484  1158  1.024159 -0.659599  1.162314  0.244697 -1.368166 -0.177201
# 895    674 -1.157098  0.580680  1.609152 -2.520580 -0.750507 -0.083799
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3231  0.984875 -0.159913  0.584435  ...  0.151025  0.803849 -0.251524
# 4001  0.037837 -0.298836  1.214750  ... -0.445632 -0.995838  0.024689
# 3355  0.832470 -0.244209  0.073695  ... -0.336424 -0.706982  0.010590
# 1484 -0.704552  0.205562  1.021309  ... -0.135463 -0.349356  0.041388
# 895  -0.244765  0.782296  0.695479  ...  0.130641  0.344185 -0.212396
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 2875  2431 -0.343128  0.615676  0.769524 -2.340985  0.603103 -0.714567
# 286    205  1.182399  0.059489  0.310673  0.828817  0.341209  1.112593
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 2875  1.030784 -0.224229  0.680863  ...  0.053958  0.487707 -0.406704
# 286  -0.292778  0.287394  0.268307  ... -0.337818 -0.776840 -0.056486
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    25
# 1.0     3
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    2171.08  0.216727  0.070533  1.004604 -0.163400 -0.291564  0.024168
# 1.0    1780.00 -2.553039  0.184644 -0.293711  2.872264  0.005330 -0.855718
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0   -0.086541  0.135634  0.636794  ...  0.067052 -0.044357  0.008171
# 1.0   -0.549831  0.308239 -1.093098  ...  0.599742  0.294921 -0.177321
#
#             V23       V24       V25       V26       V27       V28    Amount
# Class
# 0.0   -0.125965 -0.038294  0.215192 -0.006963  0.052550  0.005803   50.8416
# 1.0    0.361160 -0.020311  0.056068 -0.170050  0.015979 -0.086847  256.3100
#
# [2 rows x 30 columns]

# %% [markdown]
# **SPLITTING DATASET**

# %%
# Splitting data into features and targets
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3231  2797 -0.458755  0.605384  1.176174 -2.150163  0.300584 -0.830793
# 4001  3641  1.309282  0.399733  0.319851  0.622603  0.096517 -0.436800
# 3355  2907 -0.495710  1.156641  1.467784  0.060366 -0.112325 -1.186407
# 1484  1158  1.024159 -0.659599  1.162314  0.244697 -1.368166 -0.177201
# 895    674 -1.157098  0.580680  1.609152 -2.520580 -0.750507 -0.083799
# 2030  1573  1.085367  0.173939  1.227277  2.745296 -0.710651  0.041586
# 3485  2976  1.170003  0.104150  0.180697  1.360904 -0.156459 -0.365753
# 1449  1124  0.825069 -1.286603  0.600839 -1.342371 -1.192274  0.370953
# 4186  3750  1.385821 -0.709497 -0.924113 -1.609805  1.450344  3.277640
# 197    130  1.353283 -0.694900  0.970826 -0.426559 -1.417263 -0.505710
# 5334  5249  0.878082 -0.913507  1.995608  1.177167 -1.354109  1.803670
# 1493  1162 -0.744503  0.986800  2.281371  2.609769  0.091401  0.710918
# ...

# %%
print(Y)
# Out:
# 3231    0.0
# 4001    0.0
# 3355    0.0
# 1484    0.0
# 895     0.0
# 2030    0.0
# 3485    0.0
# 1449    0.0
# 4186    0.0
# 197     0.0
# 5334    0.0
# 1493    0.0
# 2389    0.0
# 3275    0.0
# 419     0.0
# 3292    0.0
# 5971    0.0
# 4100    0.0
# 3686    0.0
# 284     0.0
# 70      0.0
# 737     0.0
# 2721    0.0
# 2875    0.0
# 286     0.0
# 541     1.0
# 623     1.0
# 4920    1.0
# Name: Class, dtype: float64

# %%
# Splitting data into training and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=3)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (28, 30) (22, 30) (6, 30)

# %% [markdown]
# MODEL TRAINING: logistic regression model

# %%
# Loading the logistic regression model
model = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
# Training the model with dataset
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# **MODEL EVALUATION**

# %%
# Accuracy score on the training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

print('Accuracy score on training data : ', training_data_accuracy)
# Out:
# Accuracy score on training data :  1.0

# %%
# Accuracy score on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

print('Accuracy score on test data : ', test_data_accuracy)
# Out:
# Accuracy score on test data :  0.8333333333333334

# %% [markdown]
# **BUILDING A PREDICTIVE SYSTEM**

# %%
# Input data for one instance
input_data = (406,-2.3122265423263,1.95199201064158,-1.60985073229769,3.9979055875468,-0.522187864667764,-1.42654531920595,-2.53738730624579,1.39165724829804,-2.77008927719433,-2.77227214465915,3.20203320709635,-2.89990738849473,-0.595221881324605,-4.28925378244217,0.389724120274487,-1.14074717980657,-2.83005567450437,-0.0168224681808257,0.416955705037907,0.126910559061474,0.517232370861764,-0.0350493686052974,-0.465211076182388,0.320198198514526,0.0445191674731724,0.177839798284401,0.261145002567677,-0.143275874698919,0)

# Changing input data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the numpy array as we are predicting for only one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
    print('Legit Transaction')
else:
    print('Fraudulent Transaction')
# Out:
# [1.]
# Fraudulent Transaction
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
